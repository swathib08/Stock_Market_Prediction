# %% [markdown]
# <a href="https://colab.research.google.com/github/swathib08/Stock_Market_Prediction/blob/main/Stock_Market_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
import io


training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#      <input type="file" id="files-70eb95f9-df55-4c5a-b3ee-3a7a0abd49cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70eb95f9-df55-4c5a-b3ee-3a7a0abd49cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Train.csv to Google_Stock_Price_Train.csv
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 5s 10ms/step - loss: 0.2483
# Epoch 2/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.1828
# Epoch 3/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1403
# Epoch 4/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.1159
# Epoch 5/200
# 40/40 [==============================] - 0s 8ms/step - loss: 0.1024
# Epoch 6/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0957
# Epoch 7/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0923
# Epoch 8/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0903
# Epoch 9/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0887
# Epoch 10/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0873
# Epoch 11/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0859
# Epoch 12/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0844
# Epoch 13/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0830
# Epoch 14/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0816
# Epoch 15/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0801
# Epoch 16/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0787
# Epoch 17/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0772
# Epoch 18/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0757
# Epoch 19/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0742
# Epoch 20/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0727
# Epoch 21/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0713
# Epoch 22/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0697
# Epoch 23/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0682
# Epoch 24/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0667
# Epoch 25/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0651
# Epoch 26/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0635
# Epoch 27/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0619
# Epoch 28/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0604
# Epoch 29/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0587
# Epoch 30/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0571
# Epoch 31/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0554
# Epoch 32/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0537
# Epoch 33/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0521
# Epoch 34/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0503
# Epoch 35/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0486
# Epoch 36/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0467
# Epoch 37/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0450
# Epoch 38/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0432
# Epoch 39/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0414
# Epoch 40/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0395
# Epoch 41/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0377
# Epoch 42/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0358
# Epoch 43/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0340
# Epoch 44/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0321
# Epoch 45/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0303
# Epoch 46/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0285
# Epoch 47/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0267
# Epoch 48/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0249
# Epoch 49/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0232
# Epoch 50/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0215
# Epoch 51/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0198
# Epoch 52/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0182
# Epoch 53/200
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0166
# Epoch 54/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0151
# Epoch 55/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0136
# Epoch 56/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0123
# Epoch 57/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0110
# Epoch 58/200
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0098
# Epoch 59/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 60/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 61/200
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0067
# Epoch 62/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0058
# Epoch 63/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0050
# Epoch 64/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 65/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 66/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 67/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 68/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 69/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 70/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 71/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 72/200
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 73/200
# 40/40 [==============================] - 0s 4ms/step - loss: 9.5274e-04
# Epoch 74/200
# 40/40 [==============================] - 0s 3ms/step - loss: 8.1077e-04
# Epoch 75/200
# 40/40 [==============================] - 0s 4ms/step - loss: 6.9276e-04
# Epoch 76/200
# 40/40 [==============================] - 0s 5ms/step - loss: 5.9813e-04
# Epoch 77/200
# 40/40 [==============================] - 0s 4ms/step - loss: 5.2289e-04
# Epoch 78/200
# 40/40 [==============================] - 0s 5ms/step - loss: 4.6336e-04
# Epoch 79/200
# 40/40 [==============================] - 0s 6ms/step - loss: 4.1666e-04
# Epoch 80/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8058e-04
# Epoch 81/200
# 40/40 [==============================] - 0s 5ms/step - loss: 3.5300e-04
# Epoch 82/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.3128e-04
# Epoch 83/200
# 40/40 [==============================] - 0s 7ms/step - loss: 3.1645e-04
# Epoch 84/200
# 40/40 [==============================] - 0s 9ms/step - loss: 3.0296e-04
# Epoch 85/200
# 40/40 [==============================] - 0s 8ms/step - loss: 2.9430e-04
# Epoch 86/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.8846e-04
# Epoch 87/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.8309e-04
# Epoch 88/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7976e-04
# Epoch 89/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7646e-04
# Epoch 90/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.7388e-04
# Epoch 91/200
# 40/40 [==============================] - 0s 7ms/step - loss: 2.7357e-04
# Epoch 92/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.7175e-04
# Epoch 93/200
# 40/40 [==============================] - 0s 7ms/step - loss: 2.7302e-04
# Epoch 94/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7102e-04
# Epoch 95/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6969e-04
# Epoch 96/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7069e-04
# Epoch 97/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6955e-04
# Epoch 98/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6957e-04
# Epoch 99/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6901e-04
# Epoch 100/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6922e-04
# Epoch 101/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6813e-04
# Epoch 102/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.7061e-04
# Epoch 103/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.7030e-04
# Epoch 104/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6856e-04
# Epoch 105/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6776e-04
# Epoch 106/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6898e-04
# Epoch 107/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6712e-04
# Epoch 108/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6683e-04
# Epoch 109/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6983e-04
# Epoch 110/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6666e-04
# Epoch 111/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6667e-04
# Epoch 112/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6607e-04
# Epoch 113/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6587e-04
# Epoch 114/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6829e-04
# Epoch 115/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6683e-04
# Epoch 116/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6756e-04
# Epoch 117/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6519e-04
# Epoch 118/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6652e-04
# Epoch 119/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6623e-04
# Epoch 120/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6577e-04
# Epoch 121/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6623e-04
# Epoch 122/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.6557e-04
# Epoch 123/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6506e-04
# Epoch 124/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6385e-04
# Epoch 125/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6421e-04
# Epoch 126/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.6539e-04
# Epoch 127/200
# 40/40 [==============================] - 0s 6ms/step - loss: 2.6626e-04
# Epoch 128/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.6392e-04
# Epoch 129/200
# 40/40 [==============================] - 0s 5ms/step - loss: 2.6475e-04
# Epoch 130/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6947e-04
# Epoch 131/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6297e-04
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6288e-04
# Epoch 133/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6275e-04
# Epoch 134/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6185e-04
# Epoch 135/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6181e-04
# Epoch 136/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6147e-04
# Epoch 137/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6302e-04
# Epoch 138/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6070e-04
# Epoch 139/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6239e-04
# Epoch 140/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6088e-04
# Epoch 141/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6288e-04
# Epoch 142/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6700e-04
# Epoch 143/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6206e-04
# Epoch 144/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6094e-04
# Epoch 145/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6203e-04
# Epoch 146/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6146e-04
# Epoch 147/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6007e-04
# Epoch 148/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6111e-04
# Epoch 149/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5922e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5976e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6032e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6140e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5862e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6034e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6249e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6077e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6211e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6041e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6409e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5826e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5864e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5784e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5689e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5656e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5781e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5864e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5807e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5831e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5671e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5692e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5725e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5861e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5599e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5646e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5546e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5708e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5886e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5776e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5484e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5805e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5694e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5815e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5785e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6235e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5945e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5699e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5533e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5627e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5522e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5719e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5620e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6192e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5714e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5666e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5549e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5670e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5615e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5526e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.5492e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5876e-04

# %%
# getting the real stock of 2017 i.e., importing the test dataset
from google.colab import files
uploaded = files.upload()
import io
test_data = pd.read_csv('/content/Google_Stock_Price_Test.csv')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      <input type="file" id="files-fc1d938a-6041-4315-95d0-2ef27ee77166" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc1d938a-6041-4315-95d0-2ef27ee77166">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Test.csv to Google_Stock_Price_Test.csv
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
